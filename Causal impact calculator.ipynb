# %%
from causalimpact import CausalImpact
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings


# %matplotlib inline
sns.set_context('poster')
sns.set_style('darkgrid')
warnings.filterwarnings('ignore')

# %%
conv_df = pd.read_csv('C:/Users/jlwong/Desktop/test_conversion_per_day.csv')
conv_df.head()
# Out:
#    test_conversions  control_conversions       day
# 0               558                  513  1/1/2022
# 1               557                  519  1/2/2022
# 2               508                  535  1/3/2022
# 3               568                  561  1/4/2022
# 4               525                  521  1/5/2022

# %%
cost_df = pd.read_csv('C:/Users/jlwong/Desktop/test_cost_per_day.csv')

cost_df.head()
# Out:
#    test_cost  control_cost       day
# 0       5373          5784  1/1/2022
# 1       5216          5927  1/2/2022
# 2       5608          5793  1/3/2022
# 3       5358          5419  1/4/2022
# 4       5425          5620  1/5/2022

# %%
day = conv_df['day']
test_conv = conv_df['test_conversions']
control_conv = conv_df['control_conversions']

fig, ax = plt.subplots()
plt.plot(day, test_conv, color='red', marker='')
plt.plot(day, control_conv, color='blue', marker='')
plt.title('Conversions Control vs Test')
plt.xlabel('Day')
plt.ylabel('Conversions')
plt.show()

# %%
#define pre and post test periods
pre_start = '2022-01-01'
pre_end = '2022-01-14'
test_start = '2022-01-15'
test_end = '2022-01-28'


#find index values of the above dates
pre_start_ind = conv_df[conv_df.day==pre_start].index[0]
pre_end_ind = conv_df[conv_df.day==pre_end].index[0]
test_start_ind = conv_df[conv_df.day==test_start].index[0]
test_end_ind = conv_df[conv_df.day==test_end].index[0]

pre_period = [pre_start_ind,pre_end_ind]
post_period = [test_start_ind, test_end_ind]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [33], in <cell line: 9>()
#       5 test_end = '2022-01-28'
#       8 #find index values of the above dates
# ----> 9 pre_start_ind = conv_df[conv_df.day==pre_start].index[0]
#      10 pre_end_ind = conv_df[conv_df.day==pre_end].index[0]
#      11 test_start_ind = conv_df[conv_df.day==test_start].index[0]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:5053, in Index.__getitem__(self, key)
#    5050 if is_integer(key) or is_float(key):
#    5051     # GH#44051 exclude bool, which would return a 2d ndarray
#    5052     key = com.cast_scalar_indexer(key, warn_float=True)
# -> 5053     return getitem(key)
#    5055 if isinstance(key, slice):
#    5056     # This case is separated from the conditional above to avoid
#    5057     # pessimization com.is_bool_indexer and ndim checks.
# ...
